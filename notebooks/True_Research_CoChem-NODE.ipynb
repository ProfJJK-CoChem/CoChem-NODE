# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE")
tests_dir = module_dir / "tests"

print(f"[CoChem-NODE] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-NODE.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-NODE] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE
# plugins: anyio-4.10.0
# collecting ... collected 54 items
#
# tests/test_challenger_m2_stress.py::test_challenger_slurm_templater_dict_config_handling PASSED [  1%]
# tests/test_challenger_m2_stress.py::test_challenger_system_config_integrity_checksum PASSED [  3%]
# tests/test_challenger_m2_stress.py::test_challenger_local_dispatch_file_validation PASSED [  5%]
# tests/test_challenger_m2_stress.py::test_challenger_walltime_all_10_tiers_pydantic PASSED [  7%]
# tests/test_challenger_m2_stress.py::test_challenger_mps_control_rendering_combinations PASSED [  9%]
# tests/test_challenger_m2_stress.py::test_challenger_scout_anchor_partitioning_and_contention PASSED [ 11%]
# tests/test_challenger_m2_stress.py::test_challenger_schema_migration_v1_v2_to_v4 PASSED [ 12%]
# tests/test_hpc_routines.py::test_registry_lock_acquisition_and_release PASSED [ 14%]
# tests/test_hpc_routines.py::test_hpc_batcher_creation PASSED             [ 16%]
# tests/test_hpc_routines.py::test_node_orchestrator PASSED                [ 18%]
# tests/test_job_batcher.py::test_job_batcher_create_batch PASSED          [ 20%]
# tests/test_registry_manager.py::test_registry_manager PASSED             [ 22%]
# tests/test_registry_manager.py::test_registry_lock PASSED                [ 24%]
# tests/test_slurm_templater.py::test_slurm_templater_render PASSED        [ 25%]
# tests/test_v4_node_verification.py::test_node01_01_schema_version_v4 PASSED [ 27%]
# tests/test_v4_node_verification.py::test_node01_02_mps_config_presence PASSED [ 29%]
# tests/test_v4_node_verification.py::test_node01_03_core_pinning_topology PASSED [ 31%]
# tests/test_v4_node_verification.py::test_node01_04_engine_registry_completeness PASSED [ 33%]
# tests/test_v4_node_verification.py::test_node01_05_engine_tracks_and_gpu PASSED [ 35%]
# tests/test_v4_node_verification.py::test_node01_06_silos_removal PASSED  [ 37%]
# tests/test_v4_node_verification.py::test_node01_07_10_tier_walltime_budgets PASSED [ 38%]
# tests/test_v4_node_verification.py::test_node01_08_flat_24h_cap_elimination PASSED [ 40%]
# tests/test_v4_node_verification.py::test_node01_09_pydantic_schema_validation PASSED [ 42%]
# tests/test_v4_node_verification.py::test_node01_10_sha256_integrity_hash PASSED [ 44%]
# tests/test_v4_node_verification.py::test_node02_01_load_v4_defaults PASSED [ 46%]
# tests/test_v4_node_verification.py::test_node02_02_removal_of_static_caps PASSED [ 48%]
# tests/test_v4_node_verification.py::test_node02_03_walltime_lookup_t1_30min PASSED [ 50%]
# tests/test_v4_node_verification.py::test_node02_04_walltime_lookup_t4_1mo PASSED [ 51%]
# tests/test_v4_node_verification.py::test_node02_05_invalid_tier_handling PASSED [ 53%]
# tests/test_v4_node_verification.py::test_node02_06_mps_config_retrieval PASSED [ 55%]
# tests/test_v4_node_verification.py::test_node02_07_scout_anchor_allocation_retrieval PASSED [ 57%]
# tests/test_v4_node_verification.py::test_node02_08_tier_concurrency_mapping PASSED [ 59%]
# tests/test_v4_node_verification.py::test_node02_09_config_update_persistence PASSED [ 61%]
# tests/test_v4_node_verification.py::test_node02_10_validate_tier_helper PASSED [ 62%]
# tests/test_v4_node_verification.py::test_node03_01_core_pinning_injection PASSED [ 64%]
# tests/test_v4_node_verification.py::test_node03_02_mps_daemon_start_block PASSED [ 66%]
# tests/test_v4_node_verification.py::test_node03_03_mps_daemon_shutdown_block PASSED [ 68%]
# tests/test_v4_node_verification.py::test_node03_04_cpu_job_excludes_mps PASSED [ 70%]
# tests/test_v4_node_verification.py::test_node03_05_tier_walltime_resolution PASSED [ 72%]
# tests/test_v4_node_verification.py::test_node03_06_tier_walltime_1mo_resolution PASSED [ 74%]
# tests/test_v4_node_verification.py::test_node03_07_cpus_per_task_rendering PASSED [ 75%]
# tests/test_v4_node_verification.py::test_node03_08_module_loading_sequence PASSED [ 77%]
# tests/test_v4_node_verification.py::test_node03_09_scratch_dir_trap_cleanup PASSED [ 79%]
# tests/test_v4_node_verification.py::test_node03_10_resource_throttling_safety PASSED [ 81%]
# tests/test_v4_node_verification.py::test_node04_01_scout_anchor_initialization PASSED [ 83%]
# tests/test_v4_node_verification.py::test_node04_02_anchor_core_partitioning PASSED [ 85%]
# tests/test_v4_node_verification.py::test_node04_03_scout_core_partitioning PASSED [ 87%]
# tests/test_v4_node_verification.py::test_node04_04_scout_gpu_mps_binding PASSED [ 88%]
# tests/test_v4_node_verification.py::test_node04_05_contention_bound_verification_pass PASSED [ 90%]
# tests/test_v4_node_verification.py::test_node04_06_contention_bound_verification_fail PASSED [ 92%]
# tests/test_v4_node_verification.py::test_node04_07_local_mode_dispatch_fallback PASSED [ 94%]
# tests/test_v4_node_verification.py::test_node04_08_co_scheduled_pair_dispatch_payload PASSED [ 96%]
# tests/test_v4_node_verification.py::test_node04_09_temp_script_cleanup PASSED [ 98%]
# tests/test_v4_node_verification.py::test_node04_10_teardown_disconnect PASSED [100%]
#
# ============================= 54 passed in 0.43s ==============================
#
# ✅ Genuine Native Execution Complete.
